# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()           # Only displays numerical data
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde=True)

plotting('Age',1)
plotting('RestingBP',2)
plotting('Cholesterol',3)
plotting('MaxHR',4)

plt.tight_layout()

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean=df.loc[df['Cholesterol']!=0 ,'Cholesterol'].mean().__round__(2)

# %%
ch_mean
# Out:
# np.float64(244.64)

# %%
df_cleaned = df.copy()

# %%
df_cleaned['Cholesterol']=df_cleaned["Cholesterol"].replace(0,ch_mean)

# %%
df_cleaned['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 244.64    172
# 254.00     11
# 220.00     10
# 223.00     10
# 204.00      9
#          ...
# 353.00      1
# 278.00      1
# 157.00      1
# 176.00      1
# 131.00      1
# Name: count, Length: 222, dtype: int64

# %%
df_cleaned['Cholesterol']=df_cleaned['Cholesterol'].round(2)

# %%
df_cleaned['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 244.64    172
# 254.00     11
# 220.00     10
# 223.00     10
# 204.00      9
#          ...
# 353.00      1
# 278.00      1
# 157.00      1
# 176.00      1
# 131.00      1
# Name: count, Length: 222, dtype: int64

# %%
rb_mean=df.loc[df_cleaned['RestingBP']!=0 , 'RestingBP'].mean().__round__()

df_cleaned['RestingBP']=df_cleaned['RestingBP'].replace(0,rb_mean)

# %%
df_cleaned['RestingBP'].value_counts()
# Out:
# RestingBP
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
#       ...
# 101      1
# 117      1
# 192      1
# 129      1
# 164      1
# Name: count, Length: 66, dtype: int64

# %%
rb_mean
# Out:
# 133

# %%
def plottings(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df_cleaned[var],kde=True)

plottings('Age',1)
plottings('RestingBP',2)
plottings('Cholesterol',3)
plottings('MaxHR',4)

plt.tight_layout()

# %%
sns.countplot(x=df_cleaned['Sex'],hue=df_cleaned["HeartDisease"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=df_cleaned['ChestPainType'],hue=df_cleaned["HeartDisease"])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x=df_cleaned['FastingBS'],hue=df_cleaned["HeartDisease"])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.boxplot(x=df_cleaned['HeartDisease'],y = df_cleaned['Cholesterol'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x=df_cleaned['HeartDisease'],y=df_cleaned['Age'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df_cleaned.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
df_cleaned
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140        289.0          0     Normal
# 1     49   F           NAP        160        180.0          0     Normal
# 2     37   M           ATA        130        283.0          0         ST
# 3     48   F           ASY        138        214.0          0     Normal
# 4     54   M           NAP        150        195.0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110        264.0          0     Normal
# 914   68   M           ASY        144        193.0          1     Normal
# 915   57   M           ASY        130        131.0          0     Normal
# 916   57   F           ATA        130        236.0          0        LVH
# 917   38   M           NAP        138        175.0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df_encode = pd.get_dummies(df_cleaned,drop_first=True)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140        289.0          0    172      0.0             0
# 1     49        160        180.0          0    156      1.0             1
# 2     37        130        283.0          0     98      0.0             0
# 3     48        138        214.0          0    108      1.5             1
# 4     54        150        195.0          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110        264.0          0    132      1.2             1
# 914   68        144        193.0          1    141      3.4             1
# 915   57        130        131.0          0    115      1.2             1
# 916   57        130        236.0          0    174      0.0             1
# 917   38        138        175.0          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode = df_encode.astype(int)

# %%
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease', 'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_Y', 'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %% [markdown]
# # Model Training with Different Algorithms

# %% [markdown]
# Now we are going to train our data with different algorithms and check which model gives higher accuracy

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,f1_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X = df_encode.drop("HeartDisease",axis=1)

# %%
X.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA',
#        'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_Y',
#        'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %%
Y=df_encode["HeartDisease"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
models ={
    'Logistic Regression':LogisticRegression() ,
    'KNN':KNeighborsClassifier(),
    'Naive Bayes':GaussianNB(),
    'Decision Tree':DecisionTreeClassifier(),
    'SVM':SVC()
}

# %%
result = []

# %%
for name,model in models.items():
    model.fit(X_train_scaled,y_train)
    y_pred = model.predict(X_test_scaled)
    acc = accuracy_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    result.append({
        "model":name,
        "Accuracy":round(acc,4),
        "F1 Score":round(f1,4)
                   })

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.8696, 'F1 Score': 0.8857},
#  {'model': 'KNN', 'Accuracy': 0.8641, 'F1 Score': 0.8815},
#  {'model': 'Naive Bayes', 'Accuracy': 0.8533, 'F1 Score': 0.8683},
#  {'model': 'Decision Tree', 'Accuracy': 0.7826, 'F1 Score': 0.8039},
#  {'model': 'SVM', 'Accuracy': 0.8478, 'F1 Score': 0.8679}]

# %% [markdown]
# We can see that above models gave different results. The highest Acuuracy is Logistic Regression

# %%
# Now we are Saving the model in pickle format

import joblib
joblib.dump(models['KNN'],'KNN.pkl')
joblib.dump(scaler,'scaler.pkl')
joblib.dump(X.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
